# %%
pip install openml
# Out:
# Requirement already satisfied: openml in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (0.15.0)
# Requirement already satisfied: liac-arff>=2.4.0 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (2.5.0)
# Requirement already satisfied: xmltodict in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (0.14.2)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (2.32.3)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (2.2.3)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (1.14.1)
# Requirement already satisfied: numpy>=1.6.2 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (2.0.1)
# Requirement already satisfied: minio in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (7.2.9)
# Requirement already satisfied: pyarrow in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (17.0.0)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (4.66.5)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from openml) (24.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from pandas>=1.0.0->openml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from pandas>=1.0.0->openml) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from python-dateutil->openml) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from scikit-learn>=0.18->openml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from scikit-learn>=0.18->openml) (3.5.0)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from minio->openml) (2024.8.30)
# Requirement already satisfied: urllib3 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from minio->openml) (2.2.2)
# Requirement already satisfied: argon2-cffi in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from minio->openml) (21.3.0)
# Requirement already satisfied: pycryptodome in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from minio->openml) (3.21.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from minio->openml) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from requests->openml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from requests->openml) (3.7)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from tqdm->openml) (0.4.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\envs\hamdan\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
diabetes=fetch_openml(data_id=37,as_frame=True)
features=diabetes.data
Targets=diabetes.target
print(features.head())
print(Targets.head())
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age
# 0     6   148    72    35     0  33.6  0.627   50
# 1     1    85    66    29     0  26.6  0.351   31
# 2     8   183    64     0     0  23.3  0.672   32
# 3     1    89    66    23    94  28.1  0.167   21
# 4     0   137    40    35   168  43.1  2.288   33
# 0    tested_positive
# 1    tested_negative
# 2    tested_positive
# 3    tested_negative
# 4    tested_positive
# Name: class, dtype: category
# Categories (2, object): ['tested_negative', 'tested_positive']

# %%
x_train,x_test,y_train,y_test=train_test_split(features,Targets,test_size=0.2,random_state=42)
print("training set sixze",x_train.shape)
print("testing set size",x_test.shape)
# Out:
# training set sixze (614, 8)
# testing set size (154, 8)

# %%
df=GaussianNB()
df.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=df.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy of Naive Bayes classifier on Diabetes dataset: {accuracy * 100:.2f}%")
# Out:
# Accuracy of Naive Bayes classifier on Diabetes dataset: 76.62%
